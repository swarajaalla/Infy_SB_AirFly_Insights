# %% [markdown]
# # **WEEK 1 & WEEK 2 ANALYSIS**

# %%
import pandas as pd 
data=pd.read_csv("/Volumes/workspace/airlines/flight/Flight_delay.csv")
display(data.head(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
data.head(10)
# Out:
#    DayOfWeek        Date  DepTime  ...  NASDelay  SecurityDelay LateAircraftDelay
# 0          4  03-01-2019     1829  ...         0              0                32
# 1          4  03-01-2019     1937  ...         0              0                47
# 2          4  03-01-2019     1644  ...         0              0                72
# 3          4  03-01-2019     1452  ...         0              0                12
# 4          4  03-01-2019     1323  ...         0              0                16
# 5          4  03-01-2019     1416  ...         0              0                25
# 6          4  03-01-2019     1657  ...         0              0                12
# 7          4  03-01-2019     1422  ...         0              0                 7
# 8          4  03-01-2019     2107  ...         0              0                59
# 9          4  03-01-2019     1812  ...         0              0                69
#
# [10 rows x 29 columns]

# %%
data.tail(10)
# Out:
#         DayOfWeek        Date  ...  SecurityDelay  LateAircraftDelay
# 484541          7  29-06-2019  ...              0                  9
# 484542          3  04-06-2019  ...              0                 30
# 484543          7  08-06-2019  ...              0                  0
# 484544          2  10-06-2019  ...              0                  2
# 484545          4  12-06-2019  ...              0                  0
# 484546          5  13-06-2019  ...              0                  0
# 484547          6  14-06-2019  ...              0                 28
# 484548          2  17-06-2019  ...              0                 20
# 484549          7  22-06-2019  ...              0                 25
# 484550          1  23-06-2019  ...              0                  0
#
# [10 rows x 29 columns]

# %%
data.size
# Out:
# 14051979

# %%
data.dtypes
# Out:
# DayOfWeek             int64
# Date                 object
# DepTime               int64
# ArrTime               int64
# CRSArrTime            int64
# UniqueCarrier        object
# Airline              object
# FlightNum             int64
# TailNum              object
# ActualElapsedTime     int64
# CRSElapsedTime        int64
# AirTime               int64
# ArrDelay              int64
# DepDelay              int64
# Origin               object
# Org_Airport          object
# Dest                 object
# Dest_Airport         object
# Distance              int64
# TaxiIn                int64
# TaxiOut               int64
# Cancelled             int64
# CancellationCode     object
# Diverted              int64
# CarrierDelay          int64
# WeatherDelay          int64
# NASDelay              int64
# SecurityDelay         int64
# LateAircraftDelay     int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 484551 entries, 0 to 484550
# Data columns (total 29 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DayOfWeek          484551 non-null  int64
#  1   Date               484551 non-null  object
#  2   DepTime            484551 non-null  int64
#  3   ArrTime            484551 non-null  int64
#  4   CRSArrTime         484551 non-null  int64
#  5   UniqueCarrier      484551 non-null  object
#  6   Airline            484551 non-null  object
#  7   FlightNum          484551 non-null  int64
#  8   TailNum            484551 non-null  object
#  9   ActualElapsedTime  484551 non-null  int64
#  10  CRSElapsedTime     484551 non-null  int64
#  11  AirTime            484551 non-null  int64
#  12  ArrDelay           484551 non-null  int64
#  13  DepDelay           484551 non-null  int64
#  14  Origin             484551 non-null  object
# ...

# %%
print("\nMissing values per column:")
print(data.isnull().sum())
# Out:
# Missing values per column:
# DayOfWeek               0
# Date                    0
# DepTime                 0
# ArrTime                 0
# CRSArrTime              0
# UniqueCarrier           0
# Airline                 0
# FlightNum               0
# TailNum                 0
# ActualElapsedTime       0
# CRSElapsedTime          0
# AirTime                 0
# ArrDelay                0
# DepDelay                0
# Origin                  0
# Org_Airport          1177
# Dest                    0
# Dest_Airport         1479
# Distance                0
# TaxiIn                  0
# TaxiOut                 0
# Cancelled               0
# CancellationCode        0
# Diverted                0
# CarrierDelay            0
# WeatherDelay            0
# NASDelay                0
# SecurityDelay           0
# LateAircraftDelay       0
# dtype: int64

# %%
data['Org_Airport']=data['Org_Airport'].fillna("Unknown")
data['Dest_Airport']=data['Dest_Airport'].fillna("Unknown")

# %%
print("\nMissing values per column:")
print(data.isnull().sum())
# Out:
# Missing values per column:
# DayOfWeek            0
# Date                 0
# DepTime              0
# ArrTime              0
# CRSArrTime           0
# UniqueCarrier        0
# Airline              0
# FlightNum            0
# TailNum              0
# ActualElapsedTime    0
# CRSElapsedTime       0
# AirTime              0
# ArrDelay             0
# DepDelay             0
# Origin               0
# Org_Airport          0
# Dest                 0
# Dest_Airport         0
# Distance             0
# TaxiIn               0
# TaxiOut              0
# Cancelled            0
# CancellationCode     0
# Diverted             0
# CarrierDelay         0
# WeatherDelay         0
# NASDelay             0
# SecurityDelay        0
# LateAircraftDelay    0
# dtype: int64

# %%
print("Number of Duplicate Rows")
print(data.duplicated().sum())
data=data.drop_duplicates()
# Out:
# Number of Duplicate Rows
# 2

# %%
duplicate_rows = data[data.duplicated()]   
print("\nDuplicate Rows:")
print(duplicate_rows)
# Out:
# Duplicate Rows:
# Empty DataFrame
# Columns: [DayOfWeek, Date, DepTime, ArrTime, CRSArrTime, UniqueCarrier, Airline, FlightNum, TailNum, ActualElapsedTime, CRSElapsedTime, AirTime, ArrDelay, DepDelay, Origin, Org_Airport, Dest, Dest_Airport, Distance, TaxiIn, TaxiOut, Cancelled, CancellationCode, Diverted, CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, LateAircraftDelay]
# Index: []

# %%
data = data.drop_duplicates()
print("After dropping duplicates, shape:", data.shape)
# Out:
# After dropping duplicates, shape: (484549, 29)

# %%
print(df['Airline'].value_counts())
# Out:
# Airline
# Southwest Airlines Co.          119048
# American Airlines Inc.           73053
# American Eagle Airlines Inc.     58698
# United Air Lines Inc.            56896
# Skywest Airlines Inc.            50384
# US Airways Inc.                  31755
# Delta Air Lines Inc.             30220
# Atlantic Southeast Airlines      28678
# JetBlue Airways                  15364
# Alaska Airlines Inc.             10000
# Frontier Airlines Inc.            9013
# Hawaiian Airlines Inc.            1440
# Name: count, dtype: int64

# %%
data["Date"] = pd.to_datetime(data["Date"], dayfirst=True, errors="coerce")

# %%
data["DepTime"] = data["DepTime"].apply(lambda x: f"{int(x):04d}" if pd.notnull(x) else "0000")

# %%
data["DepHour"] = data["DepTime"].str[:2].astype(int)
data["DepMinute"] = data["DepTime"].str[2:].astype(int)

# %%
data["DepDatetime"] = data["Date"] + pd.to_timedelta(data["DepHour"], unit="h") + pd.to_timedelta(data["DepMinute"], unit="m")
data["Month"] = data["DepDatetime"].dt.month
data["DayOfWeek"] = data["DepDatetime"].dt.day_name()
data["Hour"] = data["DepDatetime"].dt.hour
data["Route"] = data["Origin"] + "-" + data["Dest"]

# %%
print(data[["Date", "DepTime", "DepDatetime", "Month", "DayOfWeek", "Hour", "Route"]].head())
# Out:
#         Date DepTime         DepDatetime  Month DayOfWeek  Hour    Route
# 0 2019-01-03    1829 2019-01-03 18:29:00      1  Thursday    18  IND-BWI
# 1 2019-01-03    1937 2019-01-03 19:37:00      1  Thursday    19  IND-LAS
# 2 2019-01-03    1644 2019-01-03 16:44:00      1  Thursday    16  IND-MCO
# 3 2019-01-03    1452 2019-01-03 14:52:00      1  Thursday    14  IND-PHX
# 4 2019-01-03    1323 2019-01-03 13:23:00      1  Thursday    13  IND-TPA

# %%
data
# Out:
#        DayOfWeek       Date DepTime  ...  Month  Hour    Route
# 0       Thursday 2019-01-03    1829  ...      1    18  IND-BWI
# 1       Thursday 2019-01-03    1937  ...      1    19  IND-LAS
# 2       Thursday 2019-01-03    1644  ...      1    16  IND-MCO
# 3       Thursday 2019-01-03    1452  ...      1    14  IND-PHX
# 4       Thursday 2019-01-03    1323  ...      1    13  IND-TPA
# ...          ...        ...     ...  ...    ...   ...      ...
# 484546  Thursday 2019-06-13    1609  ...      6    16  DFW-MCO
# 484547    Friday 2019-06-14    1616  ...      6    16  DFW-MCO
# 484548    Monday 2019-06-17    1617  ...      6    16  DFW-MCO
# 484549  Saturday 2019-06-22    1607  ...      6    16  DFW-MCO
# 484550    Sunday 2019-06-23    1608  ...      6    16  DFW-MCO
#
# [484549 rows x 35 columns]

# %%
data['Month'] = data['Date'].dt.month

# %%
data['DayOfWeekNum'] = data['Date'].dt.dayofweek

# %%
print(data[['Date','Month','DayOfWeekNum','Route']].head())
# Out:
#         Date  Month  DayOfWeekNum    Route
# 0 2019-01-03      1             3  IND-BWI
# 1 2019-01-03      1             3  IND-LAS
# 2 2019-01-03      1             3  IND-MCO
# 3 2019-01-03      1             3  IND-PHX
# 4 2019-01-03      1             3  IND-TPA

# %%
data['DayName'] = data['Date'].dt.day_name()
print(data[['Date', 'DayName']].head())
# Out:
#         Date   DayName
# 0 2019-01-03  Thursday
# 1 2019-01-03  Thursday
# 2 2019-01-03  Thursday
# 3 2019-01-03  Thursday
# 4 2019-01-03  Thursday

# %%
data
# Out:
#        DayOfWeek       Date DepTime  ...    Route  DayOfWeekNum   DayName
# 0       Thursday 2019-01-03    1829  ...  IND-BWI             3  Thursday
# 1       Thursday 2019-01-03    1937  ...  IND-LAS             3  Thursday
# 2       Thursday 2019-01-03    1644  ...  IND-MCO             3  Thursday
# 3       Thursday 2019-01-03    1452  ...  IND-PHX             3  Thursday
# 4       Thursday 2019-01-03    1323  ...  IND-TPA             3  Thursday
# ...          ...        ...     ...  ...      ...           ...       ...
# 484546  Thursday 2019-06-13    1609  ...  DFW-MCO             3  Thursday
# 484547    Friday 2019-06-14    1616  ...  DFW-MCO             4    Friday
# 484548    Monday 2019-06-17    1617  ...  DFW-MCO             0    Monday
# 484549  Saturday 2019-06-22    1607  ...  DFW-MCO             5  Saturday
# 484550    Sunday 2019-06-23    1608  ...  DFW-MCO             6    Sunday
#
# [484549 rows x 37 columns]

# %%
output_path =("/Volumes/workspace/airlines/flight/cleaned_dataset.csv")
data.to_csv(output_path, index=False)
