# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\adrik\Documents\Cleaned_Dataset\cleaned_dataset.csv")
df.head()
# Out:
#   DayOfWeek        Date DepTime ArrTime CRSArrTime UniqueCarrier  \
# 0  Thursday  2019-01-03   18:29   19:59      19:25            WN
# 1  Thursday  2019-01-03   19:37   20:37      19:40            WN
# 2  Thursday  2019-01-03   16:44   18:45      17:25            WN
# 3  Thursday  2019-01-03   14:52   16:40      16:25            WN
# 4  Thursday  2019-01-03   13:23   15:26      15:10            WN
#
#                   Airline  FlightNum TailNum ActualElapsedTime  ... Cancelled  \
# 0  Southwest Airlines Co.       3920  N464WN             01:30  ...         0
# 1  Southwest Airlines Co.        509  N763SW             04:00  ...         0
# 2  Southwest Airlines Co.       1333  N334SW             02:01  ...         0
# 3  Southwest Airlines Co.        675  N286WN             03:48  ...         0
# 4  Southwest Airlines Co.          4  N674AA             02:03  ...         0
#
#   CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 484549 entries, 0 to 484548
# Data columns (total 31 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DayOfWeek          484549 non-null  object
#  1   Date               484549 non-null  object
#  2   DepTime            484549 non-null  object
#  3   ArrTime            484549 non-null  object
#  4   CRSArrTime         484549 non-null  object
#  5   UniqueCarrier      484549 non-null  object
#  6   Airline            484549 non-null  object
#  7   FlightNum          484549 non-null  int64
#  8   TailNum            484549 non-null  object
#  9   ActualElapsedTime  484549 non-null  object
#  10  CRSElapsedTime     484549 non-null  object
#  11  AirTime            484549 non-null  object
#  12  ArrDelay           484549 non-null  int64
#  13  DepDelay           484549 non-null  int64
#  14  Origin             484549 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# DayOfWeek               0
# Date                    0
# DepTime                 0
# ArrTime                 0
# CRSArrTime              0
# UniqueCarrier           0
# Airline                 0
# FlightNum               0
# TailNum                 0
# ActualElapsedTime       0
# CRSElapsedTime          0
# AirTime                 0
# ArrDelay                0
# DepDelay                0
# Origin                  0
# Org_Airport          1177
# Dest                    0
# Dest_Airport         1479
# Distance                0
# TaxiIn                  0
# TaxiOut                 0
# Cancelled               0
# CancellationCode        0
# Diverted                0
# CarrierDelay            0
# WeatherDelay            0
# NASDelay                0
# SecurityDelay           0
# LateAircraftDelay       0
# Month                   0
# Route                   0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# DayOfWeek            0
# Date                 0
# DepTime              0
# ArrTime              0
# CRSArrTime           0
# UniqueCarrier        0
# Airline              0
# FlightNum            0
# TailNum              0
# ActualElapsedTime    0
# CRSElapsedTime       0
# AirTime              0
# ArrDelay             0
# DepDelay             0
# Origin               0
# Org_Airport          0
# Dest                 0
# Dest_Airport         0
# Distance             0
# TaxiIn               0
# TaxiOut              0
# Cancelled            0
# CancellationCode     0
# Diverted             0
# CarrierDelay         0
# WeatherDelay         0
# NASDelay             0
# SecurityDelay        0
# LateAircraftDelay    0
# Month                0
# Route                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Importing all the packages required for Univariate and Bivariate Visual Analysis

# %%
#finding the top 10 airlines using the barplot
top_10_airlines = df['Airline'].value_counts().nlargest(10)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_10_airlines.index, y=top_10_airlines.values)
plt.title('Top 10 Airlines')
plt.xlabel('Airline')
plt.ylabel('Number of Flights')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# finding the top 10 Routes using the barplot

# %%
top_10_routes = df['Route'].value_counts().nlargest(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_routes.values, y=top_10_routes.index, palette='viridis')
plt.title('Top 10 Routes')
plt.xlabel('Number of Flights')
plt.ylabel('Route')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\adrik\AppData\Local\Temp\ipykernel_27988\354759662.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_routes.values, y=top_10_routes.index, palette='viridis')

# %%
busiest_months = df['Month'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
sns.barplot(x=busiest_months.index, y=busiest_months.values)
plt.title('Number of Flights per Month')
plt.xlabel('Month')
plt.ylabel('Number of Flights')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# Flight distribution by day of week countplot

# %%
plt.figure(figsize=(10, 6))


day_counts = df['DayOfWeek'].value_counts(normalize=True).mul(100).sort_index()


sns.barplot(x=day_counts.index, y=day_counts.values, palette="viridis")

for i, value in enumerate(day_counts.values):
    plt.text(i, value + 0.5, f"{value:.1f}%", ha='center', fontsize=10)

plt.title('Flight Distribution by Day of Week (in %)')
plt.xlabel('Day of Week')
plt.ylabel('Percentage of Flights')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\adrik\AppData\Local\Temp\ipykernel_27988\4260666912.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=day_counts.index, y=day_counts.values, palette="viridis")

# %%
df['DepTime_datetime'] = pd.to_datetime(df['DepTime'], format='%H:%M', errors='coerce')
df['ArrTime_datetime'] = pd.to_datetime(df['ArrTime'], format='%H:%M', errors='coerce')


df['DepHour'] = df['DepTime_datetime'].dt.hour
df['ArrHour'] = df['ArrTime_datetime'].dt.hour


dep_hour_counts = df['DepHour'].value_counts().sort_index()


plt.figure(figsize=(10, 6))
sns.lineplot(x=dep_hour_counts.index, y=dep_hour_counts.values,marker="o")
plt.title('Flight Distribution by Departure Hour')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Flights')
plt.xticks(dep_hour_counts.index) 
plt.grid(True)
plt.tight_layout() 
plt.show()

# %% [markdown]
# Calculate flight counts per arrival hour

# %%
arr_hour_counts = df['ArrHour'].value_counts().sort_index()
plt.figure(figsize=(10, 6))
plt.fill_between(arr_hour_counts.index, arr_hour_counts.values, color='skyblue', alpha=0.5)
plt.plot(arr_hour_counts.index, arr_hour_counts.values, marker='o', color='blue')

plt.title('Flight Distribution by Arrival Hour (Area Plot)')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Flights')
plt.grid(alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# Calculate flight counts per origin airport

# %%
origin_airport_counts = df['Origin'].value_counts().nlargest(10)


plt.figure(figsize=(12, 6))
sns.barplot(x=origin_airport_counts.index, y=origin_airport_counts.values)
plt.title('Top 10 Origin Airports by Departures')
plt.xlabel('Origin Airport')
plt.ylabel('Number of Flights')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Calculate flight counts per destination airport

# %%
dest_airport_counts = df['Dest'].value_counts().nlargest(10)
plt.figure(figsize=(10, 6))
sns.barplot(y=dest_airport_counts.index, x=dest_airport_counts.values, palette="mako")

plt.title('Top 10 Destination Airports by Arrivals')
plt.xlabel('Number of Flights')
plt.ylabel('Destination Airport')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\adrik\AppData\Local\Temp\ipykernel_27988\549262077.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=dest_airport_counts.index, x=dest_airport_counts.values, palette="mako")

# %% [markdown]
# UNIVARIATE ANALYSIS

# %% [markdown]
# Create histograms and box plots for numerical featurrs to visualize their distribution,central tendency and spread

# %%
numerical_cols = ['FlightNum', 'ArrDelay', 'DepDelay', 'Distance', 'TaxiIn', 'TaxiOut', 'Cancelled', 'Diverted', 'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay', 'Month', 'DepHour', 'ArrHour']

for col in numerical_cols:
    # Create histogram
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=col, kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()

    # Create box plot
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=df, x=col)
    plt.title(f'Box Plot of {col}')
    plt.xlabel(col)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# BIVARIATE ANALYSIS (Numerical v/s Numerical)

# %% [markdown]
# Create scatter plots or line plots to explore the erelationship between two numerical features

# %%
# Scatter plot for DepDelay vs ArrDelay
plt.figure(figsize=(10, 6))
sns.scatterplot(x='DepDelay', y='ArrDelay', data=df, alpha=0.5)
plt.title('Relationship between Departure Delay and Arrival Delay')
plt.xlabel('Departure Delay')
plt.ylabel('Arrival Delay')
plt.grid(True)
plt.tight_layout()
plt.show()

# Scatter plot for Distance vs AirTime
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Distance', y='AirTime', data=df, alpha=0.5)
plt.title('Relationship between Distance and Air Time')
plt.xlabel('Distance')
plt.ylabel('Air Time')
plt.grid(True)
plt.tight_layout()
plt.show()

# Scatter plot for TaxiIn vs TaxiOut
plt.figure(figsize=(10, 6))
sns.scatterplot(x='TaxiIn', y='TaxiOut', data=df, alpha=0.5)
plt.title('Relationship between Taxi-In Time and Taxi-Out Time')
plt.xlabel('Taxi-In Time')
plt.ylabel('Taxi-Out Time')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Bivariate Analysis (Categorical v/s Numerical)

# %% [markdown]
# Create box plots or violin plots,potentially grouped by the categorial feature,to compare the distribution of the numeical feature across different categories

# %%
#  To visualize the distribution of 'ArrDelay' across different 'DayOfWeek'.
plt.figure(figsize=(12, 6))
sns.boxplot(x='DayOfWeek', y='ArrDelay', data=df)
plt.title('Arrival Delay Distribution by Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Arrival Delay')
plt.tight_layout()
plt.show()

# To visualize the distribution of 'DepDelay' across different 'Month'.
plt.figure(figsize=(12, 6))
sns.boxplot(x='Month', y='DepDelay', data=df)
plt.title('Departure Delay Distribution by Month')
plt.xlabel('Month')
plt.ylabel('Departure Delay')
plt.tight_layout()
plt.show()

# To visualize the distribution of 'Distance' across different 'Airline'.
plt.figure(figsize=(14, 7))
sns.boxplot(x='Airline', y='Distance', data=df)
plt.title('Distance Distribution by Airline')
plt.xlabel('Airline')
plt.ylabel('Distance')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
